# %%
from symc import SyncSimulation, SYNC_CONFIG
from symc.plotting import corner_plot, CORNER, color_plot

# %%
from rich.pretty import pprint
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Famous egg box function 🥚 by default

# %%
sim = SyncSimulation()
pprint(sim)
# Out:
# 2 dimensional egg_box simulator.

# %%
x = sim.sample(10000)
y = sim(x)

# %% [markdown]
# ### Rosenbrock function 🍌

# %%
sync_config = SYNC_CONFIG
sync_config['simulation'] = 'rosenbrock2d'
sync_config['bounds'] = [[-1.5, 1.5],[0.,2.]]
pprint(dict(sync_config))
# Out:
# {
# │   'simulation': 'rosenbrock2d',
# │   'input_dimension': 2,
# │   'output_dimension': 1,
# │   'bounds': [[-1.5, 1.5], [0.0, 2.0]],
# │   'normalised_input': False,
# │   'norm_limits': [[-1, 1]],
# │   'sim_config': None
# }

# %%
sim = SyncSimulation()

# %% [markdown]
# #### Random uniform sampling

# %%
pprint(sim.sample(3))
# Out:
# array([[-0.66016806,  0.58151949],
# │      [ 0.32202948,  1.27966482],
# │      [ 0.20173165,  0.19555392]])

# %%
x = sim.sample(10000)
y = sim(x)

# %%
labels = [r'$\theta_1$', r'$\theta_2$']
ax = color_plot(x, y, labels, cmap='Blues_r')
norm = plt.Normalize(y.min(), y.max())
sm = plt.cm.ScalarMappable(cmap="Blues_r", norm=norm)
sm.set_array([])
# Remove the legend and add a colorbar
#ax.get_legend().remove()
ax.figure.colorbar(sm, orientation='horizontal')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 labels = [r'$\theta_1$', r'$\theta_2$']
# ----> 2 ax = color_plot(x, y, labels, cmap='Blues_r')
#       3 norm = plt.Normalize(y.min(), y.max())
#       4 sm = plt.cm.ScalarMappable(cmap="Blues_r", norm=norm)
#
# File /mainfs/scratch/mjad1g20/pheno-game/toy-models/symc/src/symc/plotting.py:34, in color_plot(x, y, labels, color_label, cmap, config)
#      33 def color_plot( x, y, labels, color_label=None, cmap='Blues_r',config=None):
# ---> 34     config['plot_kws']['c'] = y
#      35     config['plot_kws']['cmap'] = cmap
#      36     g = corner_plot(x=x, labels=labels, config=config)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
from symc.likelihoods import LIKELIHOODS

# %%
lh = LIKELIHOODS['single_gaussian']

# %%
g = color_plot(x, lh(y,goal=10), labels, cmap='Blues_r')
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame(x)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
g.axes
# Out:
# array([[<AxesSubplot: ylabel='$\\theta_1$'>, None],
#        [<AxesSubplot: xlabel='$\\theta_1$', ylabel='$\\theta_2$'>,
#         <AxesSubplot: xlabel='$\\theta_2$'>]], dtype=object)

# %%
type(g)
# Out:
# seaborn.axisgrid.PairGrid

# %%
import copy 
s = 1
