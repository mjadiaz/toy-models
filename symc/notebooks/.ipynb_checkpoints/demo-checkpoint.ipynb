# %%
from simulator import Simulator
from plotting import corner_plot, CORNER, color_plot

# %%
from rich.pretty import pprint
import numpy as np
import matplotlib.pyplot as plt

# %%
sim = Simulator()
pprint(dict(sim.config))
# Out:
# {
# │   'simulation': 'egg_box',
# │   'dimension': 2,
# │   'bounds': [[10.0, 15.0]],
# │   'normalised_input': False,
# │   'norm_limits': [[-1, 1]],
# │   'sim_config': None
# }

# %% [markdown]
# #### Random uniform sampling

# %%
sim.sample(3)
# Out:
# array([[12.2995051 , 12.44017033],
#        [10.07180474, 11.08023938],
#        [13.93810431, 10.45939149]])

# %%
x = sim.sample(5000)
y = sim(x)

# %%
labels = [r'$\theta_1$', r'$\theta_2$']
g = color_plot(x, y, labels, cmap='Blues_r')
plt.show()

# %%
from likelihoods import LIKELIHOODS

# %%
lh = LIKELIHOODS['single_gaussian']

# %%
lh(y,goal=100)
# Out:
# array([[9.94766228e-06],
#        [1.01482404e-09],
#        [1.98070607e-05],
#        ...,
#        [4.05875970e-05],
#        [2.81828256e-37],
#        [1.62563335e-36]])

# %%
labels = [r'$\theta_1$', r'$\theta_2$']
g = color_plot(x, lh(y,goal=100), labels, cmap='Blues_r')
plt.show()
